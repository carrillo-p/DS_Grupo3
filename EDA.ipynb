# %% [markdown]
# # Cargamos los datos

# %%
import pandas as pd

# Carga del dataset

df = pd.read_csv('src//datasets//stroke_dataset.csv')

# Mostrar primeras filas
df.head()
# Out:
#    gender   age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  67.0             0              1          Yes        Private
# 1    Male  80.0             0              1          Yes        Private
# 2  Female  49.0             0              0          Yes        Private
# 3  Female  79.0             1              0          Yes  Self-employed
# 4    Male  81.0             0              0          Yes        Private
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban             228.69  36.6  formerly smoked       1
# 1          Rural             105.92  32.5     never smoked       1
# 2          Urban             171.23  34.4           smokes       1
# 3          Rural             174.12  24.0     never smoked       1
# 4          Urban             186.21  29.0  formerly smoked       1

# %% [markdown]
# # Exploramos el DataSet y limpiamos los datos

# %%
# Tamaño del dataset
df.shape
# Out:
# (4981, 11)

# %%
# Ver información de las columnas y el tipo de dato
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4981 entries, 0 to 4980
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gender             4981 non-null   object
#  1   age                4981 non-null   float64
#  2   hypertension       4981 non-null   int64
#  3   heart_disease      4981 non-null   int64
#  4   ever_married       4981 non-null   object
#  5   work_type          4981 non-null   object
#  6   Residence_type     4981 non-null   object
#  7   avg_glucose_level  4981 non-null   float64
#  8   bmi                4981 non-null   float64
#  9   smoking_status     4981 non-null   object
#  10  stroke             4981 non-null   int64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 428.2+ KB

# %%
# Resumen estadístico de las variables numéricas
df.describe()
# Out:
#                age  hypertension  heart_disease  avg_glucose_level  \
# count  4981.000000   4981.000000    4981.000000        4981.000000
# mean     43.419859      0.096165       0.055210         105.943562
# std      22.662755      0.294848       0.228412          45.075373
# min       0.080000      0.000000       0.000000          55.120000
# 25%      25.000000      0.000000       0.000000          77.230000
# 50%      45.000000      0.000000       0.000000          91.850000
# 75%      61.000000      0.000000       0.000000         113.860000
# max      82.000000      1.000000       1.000000         271.740000
#
#                bmi       stroke
# count  4981.000000  4981.000000
# mean     28.498173     0.049789
# std       6.790464     0.217531
# min      14.000000     0.000000
# 25%      23.700000     0.000000
# 50%      28.100000     0.000000
# 75%      32.600000     0.000000
# max      48.900000     1.000000

# %%
# Ver si hay valores nulos
df.isnull().sum()
# Out:
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
# Iterar sobre todas las columnas y mostrar los valores únicos de cada una
for column in df.columns:
    print(f"Valores únicos en la columna '{column}':")
    
    # Si la columna es 'age', convertimos los valores a enteros
    if column == 'age':
        print(df[column].astype(int).unique())
    else:
        print(df[column].unique())
    
    print("\n" + "-"*50 + "\n")
# Out:
# Valores únicos en la columna 'gender':
# ['Male' 'Female']
#
# --------------------------------------------------
#
# Valores únicos en la columna 'age':
# [67 80 49 79 81 74 69 78 61 54 50 64 75 60 71 52 82 65 57 42 48 72 58 76
#  39 77 63 73 56 45 70 59 66 43 68 47 53 38 55 46 32 51 14  3  8 37 40 35
#  20 44 25 27 23 17 13  4 16 22 30 29 11 21 18 33 24 36  0 34 41  5 26 31
#   7 12 62  2  9 15 28 10  1 19  6]
#
# --------------------------------------------------
#
# Valores únicos en la columna 'hypertension':
# [0 1]
#
# --------------------------------------------------
#
# Valores únicos en la columna 'heart_disease':
# [1 0]
#
# --------------------------------------------------
#
# Valores únicos en la columna 'ever_married':
# ['Yes' 'No']
#
# --------------------------------------------------
#
# Valores únicos en la columna 'work_type':
# ['Private' 'Self-employed' 'Govt_job' 'children']
#
# --------------------------------------------------
#
# ...

# %% [markdown]
# Descripción de las columnas del dataset
#
# gender:
#
# El género del individuo.
# Valores posibles: Male (masculino), Female (femenino).
#
# age:
#
# La edad del individuo en años.
# Valores: float (e.g., 80, 49).
#
# hypertension:
#
# Indica si el individuo tiene hipertensión.
# Valores: 0 (no tiene hipertensión), 1 (tiene hipertensión).
#
# heart_disease:
#
# Indica si el individuo tiene enfermedad cardíaca.
# Valores: 0 (no tiene enfermedad cardíaca), 1 (tiene enfermedad cardíaca).
#
# ever_married:
#
# Indica si el individuo se ha casado alguna vez.
# Valores: Yes (sí), No (no).
#
# work_type:
#
# Tipo de trabajo que realiza el individuo.
# Valores posibles:
# Private: Empleado en el sector privado.
# Self-employed: Trabajador autónomo.
# Govt_job: Empleado en el sector público.
# Children: Menores de edad.
# Never_worked: Nunca ha trabajado.
#
# Residence_type:
#
# Tipo de residencia del individuo.
# Valores: Urban (urbano), Rural (rural).
#
# avg_glucose_level:
#
# Nivel promedio de glucosa en sangre (medido en mg/dL).
# Valores: Números decimales que indican la glucosa promedio (e.g., 105.92).
#
# bmi:
#
# Índice de masa corporal, una medida de la relación entre el peso y la altura de una persona.
# Valores: Números decimales que representan el BMI (e.g., 32.5).
#
# smoking_status:
#
# Estado del tabaquismo del individuo.
# Valores posibles:
# never smoked: nunca ha fumado.
# formerly smoked: ha fumado en el pasado, pero no actualmente.
# smokes: fuma actualmente.
# Unknown: se desconoce el estado de tabaquismo.
#
# stroke:
#
# Variable a predecir ICTUS.
# Indica si el individuo ha tenido un accidente cerebrovascular (ACV).
# Valores: 0 (no ha tenido un ACV), 1 (ha tenido un ACV).

# %% [markdown]
# Observamos que no tenemos ningún valor NaN en el DataSet, sin embargo en la columna 'smoking status' tenemos valores de 'Unknown' y en la columna age, tenemos valores con bastantes decimales, por lo que vamos a filtrar para ver los valores menores de 1, y filtraremos tambien para contar cuantos 'Unknown' tenemos.

# %%
# Filtrar las filas donde 'age' es menor a 1
age_menor_a_1 = df[df['age'] < 1]

# Contar el número de 'Unknown' en 'smoking_status'
desconocidos = df['smoking_status'].value_counts().get('Unknown', 0)

# Mostrar los valores únicos de 'age' menores a 1 y su conteo en formato float
print(age_menor_a_1['age'].value_counts().sort_index().astype(float))

# Mostrar el número de veces que aparece 'Unknown' en 'smoking_status'
print(f"Número de 'Unknown' en 'smoking_status': {desconocidos}")
# Out:
# age
# 0.08    2.0
# 0.16    1.0
# 0.24    5.0
# 0.32    5.0
# 0.40    2.0
# 0.48    3.0
# 0.56    5.0
# 0.64    4.0
# 0.72    5.0
# 0.80    4.0
# 0.88    5.0
# Name: count, dtype: float64
# Número de 'Unknown' en 'smoking_status': 1500

# %% [markdown]
# Con esto observamos que 1500 de 4981 valores en 'smoking_status' son desconocidos, por lo que es una cifra muy elevada y vamos a realizar comprobaciones para su imputación.
#
# Teniendo en cuenta que la edad mínima para fumar son 18 años, filtraremos el dataset por edad de menos de 18 e imputaremos el valor por: 'never smoked'

# %%
# Filtrar las personas menores de 18 años con 'Unknown' en 'smoking_status'
menores_18_unknown = df[(df['age'] < 18) & (df['smoking_status'] == 'Unknown')]

# Mostrar el conteo de personas menores de 18 años con 'Unknown' en 'smoking_status' y con 'never_smoked' antes de la imputación
conteo_menores_18_unknown = menores_18_unknown.shape[0]
conteo_never_smoked_antes = df[(df['age'] < 18) & (df['smoking_status'] == 'never smoked')].shape[0]
print(f"Conteo de personas menores de 18 años con 'Unknown' en 'smoking_status' antes de la imputación: {conteo_menores_18_unknown}")
print(f"Conteo de personas menores de 18 años con 'never smoked' en 'smoking_status' antes de la imputación: {conteo_never_smoked_antes}")

# Imputar el valor 'never smoked' a estas personas
df.loc[(df['age'] < 18) & (df['smoking_status'] == 'Unknown'), 'smoking_status'] = 'never smoked'

# Verificar el conteo después de la imputación
conteo_menores_18_unknown_despues = df[(df['age'] < 18) & (df['smoking_status'] == 'Unknown')].shape[0]
conteo_never_smoked_despues = df[(df['age'] < 18) & (df['smoking_status'] == 'never smoked')].shape[0]
print(f"Conteo de personas menores de 18 años con 'Unknown' en 'smoking_status' después de la imputación: {conteo_menores_18_unknown_despues}")
print(f"Conteo de personas menores de 18 años con 'never smoked' en 'smoking_status' después de la imputación: {conteo_never_smoked_despues}")
# Out:
# Conteo de personas menores de 18 años con 'Unknown' en 'smoking_status' antes de la imputación: 661
# Conteo de personas menores de 18 años con 'never smoked' en 'smoking_status' antes de la imputación: 128
# Conteo de personas menores de 18 años con 'Unknown' en 'smoking_status' después de la imputación: 0
# Conteo de personas menores de 18 años con 'never smoked' en 'smoking_status' después de la imputación: 789

# %%
# Volvemos a calcular los valores de 'Unknown' después de la imputación
desconocidos = df['smoking_status'].value_counts().get('Unknown', 0)

# Mostrar el número de veces que aparece 'Unknown' en 'smoking_status'
print(f"Número de 'Unknown' en 'smoking_status': {desconocidos}")
# Out:
# Número de 'Unknown' en 'smoking_status': 839

# %% [markdown]
# El resto de valores 'Unkown' vamos a imputarlos por KNN, para ello primero es necesario convertir las columnas categóricas a numéricas, para que KNN pueda calcular las distancias.
#
# Pero antes vamos a tratar la columna de work_type, ya que tenemos un valor que es 'children', que podriamos simplificar si realmente todos los que tienen 'children' son menores de 16 años, podemos imputar el valor a 'Never_worked' para simplificarlo.

# %%
# Filtrar las personas menores de 16 años con 'children' en la columna 'work_type'
menores_con_children = df[(df['age'] < 16) & (df['work_type'] == 'children')]

# Contar las personas menores de 16 con 'children' antes de la imputación
conteo_antes_imputacion = menores_con_children.shape[0]
print(f"Conteo de personas menores de 16 años con 'children' antes de la imputación: {conteo_antes_imputacion}")

# Imputar el valor 'Never_worked' para los menores de 16 con 'children'
df.loc[(df['age'] < 16) & (df['work_type'] == 'children'), 'work_type'] = 'Never_worked'

# Verificar si el cambio se ha realizado correctamente, mostrando el conteo después de la imputación
personas_con_children_post_imputacion = df[df['work_type'] == 'children']
conteo_post_imputacion = personas_con_children_post_imputacion.shape[0]
print(f"Conteo de personas con 'children' después de la imputación: {conteo_post_imputacion}")

# Mostrar las personas que aún tienen 'children' en 'work_type'
print("Personas que aún tienen 'children' en 'work_type':")
personas_con_children_post_imputacion
# Out:
# Conteo de personas menores de 16 años con 'children' antes de la imputación: 662
# Conteo de personas con 'children' después de la imputación: 11
# Personas que aún tienen 'children' en 'work_type':
#       gender   age  hypertension  heart_disease ever_married work_type  \
# 247   Female  16.0             0              0           No  children
# 409   Female  16.0             0              0           No  children
# 840   Female  16.0             0              0           No  children
# 1345    Male  16.0             0              0           No  children
# 2344    Male  16.0             0              0           No  children
# 3115    Male  16.0             0              0           No  children
# 3457  Female  16.0             0              0           No  children
# 3739    Male  16.0             0              0           No  children
# 4241    Male  16.0             0              0           No  children
# ...

# %% [markdown]
# Observamos que los 11 sujetos restantes tienen 16 años, asumimos que al tener 16 años y la variable en children, figura como Never_worked, por lo que imputamos tambien.

# %%
df.loc[df['work_type'] == 'children', 'work_type'] = 'Never_worked'

# Verificar si 'children' aún existe en el dataset
print("\nValores únicos en 'work_type' después de la imputación:")
print(df['work_type'].value_counts())
# Out:
# Valores únicos en 'work_type' después de la imputación:
# work_type
# Private          2860
# Self-employed     804
# Never_worked      673
# Govt_job          644
# Name: count, dtype: int64

# %% [markdown]
# Después de la comprobación, convertimos las variables categóricas a numéricas, para poder imputar los valores de la columna 'smoking_status' por KNN. Aplicamos la técnica de KNN para imputar valores faltantes en smoking_status usando 5 vecinos, porque no hay una correlación clara con otras variables.

# %%
from sklearn.impute import KNNImputer
import numpy as np

# Conversión manual de las variables categóricas a numéricas
df['gender'] = df['gender'].map({'Male': 0, 'Female': 1})
df['ever_married'] = df['ever_married'].map({'Yes': 1, 'No': 0})
df['Residence_type'] = df['Residence_type'].map({'Urban': 0, 'Rural': 1})
work_type_mapping= {
    'Private': 0,
    'Self-employed': 1,
    'Govt_job': 2,
    'Never_worked': 3,
}
df['work_type'] = df['work_type'].map(work_type_mapping)

# Convertir la columna 'smoking_status' a numérica para usarla con KNN
smoking_status_mapping = {'never smoked': 0, 'formerly smoked': 1, 'smokes': 2, 'Unknown': np.nan}
df['smoking_status'] = df['smoking_status'].map(smoking_status_mapping)

# Definir el imputador KNN 
imputer = KNNImputer(n_neighbors=5)

# Imputar los valores faltantes en la columna 'smoking_status' solamente
df[['smoking_status']] = imputer.fit_transform(df[['smoking_status']])

# Convertir de nuevo las columnas categóricas a su forma original (entero)
df['gender'] = df['gender'].astype(int)
df['ever_married'] = df['ever_married'].astype(int)
df['Residence_type'] = df['Residence_type'].astype(int)
df['work_type'] = df['work_type'].astype(int)
df['smoking_status'] = df['smoking_status'].round().astype(int)

# Mostrar el conteo después de la imputación
print(df['smoking_status'].value_counts())

# Verificar que las demás columnas sigan como numéricas y el resultado de las primeras filas
print(df.head())
# Out:
# smoking_status
# 0    2499
# 1    1706
# 2     776
# Name: count, dtype: int64
#    gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0       0  67.0             0              1             1          0
# 1       0  80.0             0              1             1          0
# 2       1  49.0             0              0             1          0
# 3       1  79.0             1              0             1          1
# 4       0  81.0             0              0             1          0
#
#    Residence_type  avg_glucose_level   bmi  smoking_status  stroke
# 0               0             228.69  36.6               1       1
# 1               1             105.92  32.5               0       1
# 2               0             171.23  34.4               2       1
# 3               1             174.12  24.0               0       1
# 4               0             186.21  29.0               1       1

# %% [markdown]
# Tras analizar los pesos y las importancias de las características, hemos decidido dividivir las caracterisiticas más influyentes en grupos, para esperar un mejor rendimiento del modelo.

# %%
# Dividir la edad en grupos 
def categorize_age(age):
    if age < 18:
        return 'Menor de 18'
    elif 18 <= age < 40:
        return '18-39'
    elif 40 <= age < 60:
        return '40-59'
    else:
        return 'Mayor de 60'

# Aplicar la función de categorización de edad
df['age_group'] = df['age'].apply(categorize_age)

# Categorización del BMI (Índice de Masa Corporal) según los rangos médicos comunes
def categorize_bmi(bmi):
    if bmi < 18.5:
        return 'Bajo peso'
    elif 18.5 <= bmi < 24.9:
        return 'Normal'
    elif 25 <= bmi < 29.9:
        return 'Sobrepeso'
    else:
        return 'Obesidad'

# Aplicar la función de categorización de BMI
df['bmi_group'] = df['bmi'].apply(categorize_bmi)

# Categorización de los niveles de glucosa en sangre
def categorize_glucose(glucose):
    if glucose < 90:
        return 'Bajo'
    elif 90 <= glucose < 120:
        return 'Normal'
    elif 120 <= glucose < 160:
        return 'Medio'
    else:
        return 'Alto'

# Aplicar la función de categorización de glucosa
df['glucose_group'] = df['avg_glucose_level'].apply(categorize_glucose)

# Mostrar las primeras filas del dataframe con las nuevas columnas categorizadas
print(df[['age_group', 'bmi_group', 'glucose_group']].head())
# Out:
#      age_group  bmi_group glucose_group
# 0  Mayor de 60   Obesidad          Alto
# 1  Mayor de 60   Obesidad        Normal
# 2        40-59   Obesidad          Alto
# 3  Mayor de 60     Normal          Alto
# 4  Mayor de 60  Sobrepeso          Alto

# %%
# Convertir las categorías de age_group a numéricas
age_mapping = {
    'Menor de 18': 0,
    '18-39': 1,
    '40-59': 2,
    'Mayor de 60': 3
}
df['age_group'] = df['age_group'].map(age_mapping)

# Convertir las categorías de bmi_group a numéricas
bmi_mapping = {
    'Bajo peso': 0,
    'Normal': 1,
    'Sobrepeso': 2,
    'Obesidad': 3
}
df['bmi_group'] = df['bmi_group'].map(bmi_mapping)

# Convertir las categorías de glucose_group a numéricas
glucose_mapping = {
    'Bajo': 0,
    'Normal': 1,
    'Medio': 2,
    'Alto': 3
}
df['glucose_group'] = df['glucose_group'].map(glucose_mapping)

# Mostrar las primeras filas del dataframe con las columnas categorizadas en numérico
print(df[['age_group', 'bmi_group', 'glucose_group']].head())
# Out:
#    age_group  bmi_group  glucose_group
# 0          3          3              3
# 1          3          3              1
# 2          2          3              3
# 3          3          1              3
# 4          3          2              3

# %%
# Borrar columnas anteriores
df.drop(['age', 'bmi', 'avg_glucose_level'], axis=1, inplace=True)

# %%
# Iterar sobre todas las columnas y mostrar los valores únicos de cada una
for column in df.columns:
    print(f"Valores únicos en la columna '{column}':")
    
    # Si la columna es 'age', convertimos los valores a enteros
    if column == 'age':
        print(df[column].astype(int).unique())
    else:
        print(df[column].unique())
    
    print("\n" + "-"*50 + "\n")
# Out:
# Valores únicos en la columna 'gender':
# [0 1]
#
# --------------------------------------------------
#
# Valores únicos en la columna 'hypertension':
# [0 1]
#
# --------------------------------------------------
#
# Valores únicos en la columna 'heart_disease':
# [1 0]
#
# --------------------------------------------------
#
# Valores únicos en la columna 'ever_married':
# [1 0]
#
# --------------------------------------------------
#
# Valores únicos en la columna 'work_type':
# [0 1 2 3]
#
# --------------------------------------------------
#
# Valores únicos en la columna 'Residence_type':
# [0 1]
#
# --------------------------------------------------
#
# Valores únicos en la columna 'smoking_status':
# [1 0 2]
#
# --------------------------------------------------
#
# Valores únicos en la columna 'stroke':
# [1 0]
#
# --------------------------------------------------
#
# Valores únicos en la columna 'age_group':
# [3 2 1 0]
#
# ...

# %%
# Verificar si hay valores negativos en las columnas numéricas
print("\nVerificación de valores negativos:")
negative_values = df[df.select_dtypes(include=[np.number]) < 0].any()
print(negative_values)
# Out:
# Verificación de valores negativos:
# gender            False
# hypertension      False
# heart_disease     False
# ever_married      False
# work_type         False
# Residence_type    False
# smoking_status    False
# stroke            False
# age_group         False
# bmi_group         False
# glucose_group     False
# dtype: bool

# %%
# Verificar si hay duplicados
print("\nVerificar si hay duplicados:")
duplicates = df.duplicated().sum()
print(f"Número de duplicados: {duplicates}")
# Out:
# Verificar si hay duplicados:
# Número de duplicados: 3073

# %% [markdown]
# Graficos y estadísticas

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Heatmap de correlación entre variables numéricas
corr = df.corr()
plt.figure(figsize=(10, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Mapa de calor de correlaciones')
plt.show()

# %% [markdown]
# Con este gráfico de correlaciones, no detectamos ningún patron mortante, las unicas corelaciones que podemos observar es un aumento de 'ever_married' en función del aumento de 'age', esto como correlación más fuerte, pero supondría solo un 0.68. Y la siguiente correlación podria ser el aumento de 'bmi' en funcion de 'age' y 'ever_married', pero no es una correlación muy relevante.
#
# Ahora vamos a realizar gráficos de bloxplot para analizar y detectar posibles outliers:

# %%
for column in df.columns:
    plt.figure(figsize=(8, 4))
    sns.boxplot(x=df[column])
    plt.title(f'Boxplot de la variable: {column}')
    plt.show()

# %% [markdown]
# Analizando los gráficos podemos detectar la presencia de outliers en 'avg_glucose_level' y en 'bmi'.
#
# En el caso de 'avg_glucose_level': La caja muestra que la mayoría de los datos están entre aproximadamente 80 y 120 de nivel promedio de glucosa, lo que se correspondería con valores normales de glucosa en sangre.
# La mediana, está alrededor de 100, lo que indica que la mitad de las personas tienen niveles de glucosa por debajo de 100 y la otra mitad por encima. Hay outliers visibles hacia la derecha del boxplot (más allá de 150), lo que indica que hay algunas personas con niveles de glucosa muy altos, mucho más allá del rango típico, lo que podría representar un riesgo de diabetes o problemas de salud.
#
# En el caso de 'bmi': La mayoría de los datos de BMI se encuentran entre aproximadamente 25 y 30, lo que cae en el rango de peso normal a sobrepeso.
# La mediana está en torno a 27.5, lo que sugiere que una gran parte de las personas tienen un BMI en el rango de sobrepeso.
# Los "bigotes" van desde aproximadamente 15 hasta 45, lo que indica que algunos pacientes tienen un BMI bajo o muy alto.
# Los outliers en el lado derecho, con valores por encima de 45, indican que hay personas con obesidad severa, lo que podría ser un factor de riesgo importante para el ictus.
#
# En el caso de 'smoking_status': La caja se extiende principalmente entre los valores 0 (nunca ha fumado) y 1 (ha fumado anteriormente), lo que indica que la mayoría de los datos caen en estas dos categorías. La mediana en 1 sugiere que muchas personas en este conjunto de datos han fumado anteriormente.
# El "bigote" hacia la derecha llega hasta el valor 2, lo que indica que hay algunas personas que actualmente fuman, pero es un grupo más pequeño en comparación con los que nunca fumaron o fumaron anteriormente.
#
# En el caso de 'work_type': La mayoría de las personas en el conjunto de datos están empleadas en trabajos privados o son autónomos. Pocos trabajan para el gobierno, y casi nadie parece no haber trabajado nunca.
#
# Por lo que podriamos decir que los valores de outliers en 'avg_glucose_level' y 'bmi', podrían suponer un alto factor para producirse un ictus.
#
# Tambien podria ser desencadenante tanto la variable de enfermedad cardíaca, como la de hipertensión.
#
# Dado que los outliers no representan valores que se salgan de los rangos posibles en terminos de mediciones de salud, decidimos no realizar un tratamiento de ellos.

# %% [markdown]
# Ahora vamos a analizar como están distribuidos los mediante histogramas, para aclarar más la visión del dataset.

# %%
import matplotlib.pyplot as plt

# Filtramos solo las columnas numéricas
numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns

# Recorrer todas las columnas numéricas
for col in numeric_columns:
    # Crear una nueva figura para cada gráfico
    plt.figure()
    
    # Crear histograma para la columna actual
    df[col].hist(bins=30)
    
    # Configurar el título y etiquetas de los ejes
    plt.title(f'Distribución de la variable: {col}')
    plt.xlabel(col)
    plt.ylabel('Frecuencia')
    
    # Mostrar el gráfico
    plt.show()

# %% [markdown]
# Con estos datos podemos observamos, que las muestras de la variable predictora estan muy desbalanceadas, lo que podría perjudicar al rendimiento del modelo.
#
# En base a estos datos, vamos a realizar gráficos que relacionen a variables que pueden tener relevancia con la variable a predecir, como son: 'bmi', 'avg_glucose_level', 'heart_disease', 'hypertension' y 'smoking status'

# %%
'''
# Para variables continuas
continuous_vars = ['bmi', 'avg_glucose_level']

# Crear gráficos de boxplot
for var in continuous_vars:
    plt.figure()
    sns.boxplot(x=df['stroke'], y=df[var])
    plt.title(f'Distribución de {var} por stroke')
    plt.xlabel('stroke')
    plt.ylabel(var)
    plt.show()

'''
# Out:
# "\n# Para variables continuas\ncontinuous_vars = ['bmi', 'avg_glucose_level']\n\n# Crear gráficos de boxplot\nfor var in continuous_vars:\n    plt.figure()\n    sns.boxplot(x=df['stroke'], y=df[var])\n    plt.title(f'Distribución de {var} por stroke')\n    plt.xlabel('stroke')\n    plt.ylabel(var)\n    plt.show()\n\n"

# %% [markdown]
# En estos gráficos en la variable de bmi, no podemos ver una tendencia clara, pero en 'avg_glucose_level' si podemos obervar, que los casos de ictus, se dan en su mayoría en los valores de glucosa a partir de 120, por lo que si podría representar un factor influyente.

# %%
# Para variables categóricas
categorical_vars = ['heart_disease', 'hypertension', 'smoking_status', 'age_group', 'bmi_group', 'glucose_group']

# Crear gráficos de barras
for var in categorical_vars:
    plt.figure()
    sns.countplot(x=df[var], hue=df['stroke'], palette='Set2')
    plt.title(f'Proporción de stroke en función de {var}')
    plt.xlabel(var)
    plt.ylabel('Cuenta')
    plt.show()

# %% [markdown]
# Podemos observar en los gráficos de 'heart_disease' e 'hypertension', que si tienen alguna de esas variables, el riesgo de sufrir un ictus esta más igualado, ya que si no la presentan el gráfico muestra claramente que será muy dificil que sufran un ictus.
# Igual que en smoking_status, la probabilidad va igualandose y subiendo la probabilidad de sufrir ictus, segun aumenta la variable de fumador.

# %% [markdown]
# Vamos a calcular la asimetría:

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import skew

# Calcular la asimetría de las columnas numéricas
asimetria = df.skew()

# Mostrar la asimetría de cada columna
print(asimetria)
# Out:
# gender           -0.339351
# hypertension      2.740377
# heart_disease     3.896191
# ever_married     -0.668689
# work_type         0.955789
# Residence_type    0.033341
# smoking_status    0.643176
# stroke            4.140942
# age_group        -0.213350
# bmi_group        -0.502312
# glucose_group     0.960013
# dtype: float64

# %% [markdown]
# Variables con alta asimetría positiva (por ejemplo, "Hypertension", "Heart Disease", "Avg Glucose Level", "Stroke") indican que la mayoría de los valores están en el extremo inferior (0), con algunas observaciones en los valores superiores.
#
# Para las variables categóricas como "Hypertension", "Heart Disease" y "Stroke", no es necesario hacer transformaciones porque son indicadoras de presencia o ausencia.
#
# Para la variable "Avg Glucose Level", podríamos considerar una transformación logarítmica o raíz cuadrada si necesitamos normalizar los datos para algún análisis estadístico.
#
# Variables con asimetría negativa (por ejemplo, "Gender", "Ever Married") muestran que los valores más altos son más comunes (por ejemplo, más personas casadas que solteras). Al ser variables categóricas o binarias, no es necesario transformarlas.
#
# Asimetría cercana a 0 en variables como "Age" y "Residence Type" sugiere que estas variables están distribuidas de manera relativamente simétrica, lo cual es positivo, ya que no requieren transformaciones para muchos análisis.

# %% [markdown]
# # Transformaciones y preprocesamiento

# %%
'''
# Aplicar transformación logarítmica a la variable
df['avg_glucose_level'] = np.log1p(df['avg_glucose_level'])

'''
# Out:
# "\n# Aplicar transformación logarítmica a la variable\ndf['avg_glucose_level'] = np.log1p(df['avg_glucose_level'])\n\n"

# %% [markdown]
# Aunque en RandomForest no es estrictamente necesario escalar las variables, voy a realizar la estandarización de las variables, por si utilizamos estos datos en un futuro con otros algoritmos.

# %%
'''
from sklearn.preprocessing import StandardScaler

# Definir las columnas a estandarizar
columns_to_scale = ['age', 'avg_glucose_level', 'bmi']

# Inicializar el escalador
scaler = StandardScaler()

# Aplicar la estandarización
df[columns_to_scale] = scaler.fit_transform(df[columns_to_scale])

'''
# Out:
# "\nfrom sklearn.preprocessing import StandardScaler\n\n# Definir las columnas a estandarizar\ncolumns_to_scale = ['age', 'avg_glucose_level', 'bmi']\n\n# Inicializar el escalador\nscaler = StandardScaler()\n\n# Aplicar la estandarización\ndf[columns_to_scale] = scaler.fit_transform(df[columns_to_scale])\n\n"

# %% [markdown]
# Dividir datos en entrenamiento y prueba.

# %%
from sklearn.model_selection import train_test_split

# Dividir en características (X) y la variable objetivo (y)
X = df.drop('stroke', axis=1)
y = df['stroke']

'''

# Dividir en entrenamiento (train) y prueba (test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

'''
# Out:
# '\n\n# Dividir en entrenamiento (train) y prueba (test)\nX_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)\n\n'

# %%
import optuna
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score

# Dividir los datos
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

def objective(trial):
    # Definir el espacio de búsqueda
    n_estimators = trial.suggest_int('n_estimators', 50, 300)
    max_depth = trial.suggest_int('max_depth', 3, 30)
    min_samples_split = trial.suggest_int('min_samples_split', 2, 10)
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 4)

    # Crear el modelo
    model = RandomForestClassifier(n_estimators=n_estimators,
                                   max_depth=max_depth,
                                   min_samples_split=min_samples_split,
                                   min_samples_leaf=min_samples_leaf,
                                   random_state=42)

    # Entrenar el modelo
    model.fit(X_train, y_train)
    
    # Hacer predicciones
    y_pred = model.predict(X_test)
    
    # Retornar la métrica de interés (F1-score)
    return f1_score(y_test, y_pred)



# Crear un estudio y optimizarlo
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)

# Verificar si el estudio ha encontrado los mejores parámetros
if study.best_params:
    # Obtener los mejores hiperparámetros
    best_params = study.best_params
    print("Best parameters:", best_params)
else:
    raise ValueError("No best parameters found. The optimization may have failed.")
# Out:
# [I 2024-10-09 17:51:56,584] A new study created in memory with name: no-name-ac058c00-30e5-4560-be51-7bf87e694d99
# [I 2024-10-09 17:51:57,030] Trial 0 finished with value: 0.0 and parameters: {'n_estimators': 293, 'max_depth': 8, 'min_samples_split': 7, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.0.
# [I 2024-10-09 17:51:57,530] Trial 1 finished with value: 0.047058823529411764 and parameters: {'n_estimators': 298, 'max_depth': 12, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 1 with value: 0.047058823529411764.
# [I 2024-10-09 17:51:57,606] Trial 2 finished with value: 0.0 and parameters: {'n_estimators': 56, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 4}. Best is trial 1 with value: 0.047058823529411764.
# [I 2024-10-09 17:51:58,093] Trial 3 finished with value: 0.0 and parameters: {'n_estimators': 297, 'max_depth': 23, 'min_samples_split': 2, 'min_samples_leaf': 3}. Best is trial 1 with value: 0.047058823529411764.
# ...

# %% [markdown]
# Preparación y entrenamiento del modelo (RandomForest)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score, roc_auc_score

# Inicializar el modelo RandomForest con los mejores hiperparámetros obtenidos
rf_model = RandomForestClassifier(
    n_estimators=best_params['n_estimators'],
    max_depth=best_params['max_depth'],
    min_samples_split=best_params['min_samples_split'],
    min_samples_leaf=best_params['min_samples_leaf'],
    random_state=42
)

# Entrenar el modelo con los datos de entrenamiento
rf_model.fit(X_train, y_train)

# Hacer predicciones con los datos de prueba
y_pred = rf_model.predict(X_test)

# Evaluar el rendimiento del modelo final
print("Accuracy:", accuracy_score(y_test, y_pred))
print("ROC-AUC Score:", roc_auc_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9411371237458194
# ROC-AUC Score: 0.5207010115266996
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      1417
#            1       0.22      0.05      0.08        78
#
#     accuracy                           0.94      1495
#    macro avg       0.59      0.52      0.53      1495
# weighted avg       0.91      0.94      0.92      1495

# %%
'''
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score, roc_auc_score

# Inicializar el modelo RandomForest
rf_model = RandomForestClassifier(random_state=42)

# Entrenar el modelo con los datos de entrenamiento
rf_model.fit(X_train, y_train)

# Hacer predicciones con los datos de prueba
y_pred = rf_model.predict(X_test)

# Evaluar el rendimiento del modelo
print("Accuracy:", accuracy_score(y_test, y_pred))
print("ROC-AUC Score:", roc_auc_score(y_test, y_pred))
print(classification_report(y_test, y_pred))

'''
# Out:
# '\nfrom sklearn.ensemble import RandomForestClassifier\nfrom sklearn.metrics import classification_report, accuracy_score, roc_auc_score\n\n# Inicializar el modelo RandomForest\nrf_model = RandomForestClassifier(random_state=42)\n\n# Entrenar el modelo con los datos de entrenamiento\nrf_model.fit(X_train, y_train)\n\n# Hacer predicciones con los datos de prueba\ny_pred = rf_model.predict(X_test)\n\n# Evaluar el rendimiento del modelo\nprint("Accuracy:", accuracy_score(y_test, y_pred))\nprint("ROC-AUC Score:", roc_auc_score(y_test, y_pred))\nprint(classification_report(y_test, y_pred))\n\n'

# %% [markdown]
# Verificar si el modelo está balanceado

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Calcular la matriz de confusión
cm = confusion_matrix(y_test, y_pred)

# Mostrar la matriz de confusión
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

# %% [markdown]
# Análisis del Balance de Clases

# %%
# Contar la clase objetivo
print(df['stroke'].value_counts(normalize=True))
# Out:
# stroke
# 0    0.950211
# 1    0.049789
# Name: proportion, dtype: float64

# %% [markdown]
# Este desbalance de clases tan significativo, influye negativamente en el rendimiento del modelo, por lo que vamos a tratarlo antes del entrenamiento. Utilizaremos la técnica de Oversampling. Esta técnica aumenta la cantidad de ejemplos en la clase minoritaria mediante la replicación de ejemplos existentes o la creación de ejemplos sintéticos, como lo hace SMOTE (Synthetic Minority Over-sampling Technique).

# %% [markdown]
# Balanceo de clases

# %%
'''

from imblearn.over_sampling import SMOTE

# Aplicar SMOTE para el balanceo de clases
smote = SMOTE(random_state=42)
X_train_balanced, y_train_balanced = smote.fit_resample(X_train, y_train)

# Reentrenar el modelo con los datos balanceados
rf_model_balanced = RandomForestClassifier(random_state=42)
rf_model_balanced.fit(X_train_balanced, y_train_balanced)

# Hacer predicciones nuevamente
y_pred_balanced = rf_model_balanced.predict(X_test)

# Evaluar el modelo balanceado
print("Accuracy:", accuracy_score(y_test, y_pred_balanced))
print("ROC-AUC Score:", roc_auc_score(y_test, y_pred_balanced))
print(classification_report(y_test, y_pred_balanced))

'''
# Out:
# '\n\nfrom imblearn.over_sampling import SMOTE\n\n# Aplicar SMOTE para el balanceo de clases\nsmote = SMOTE(random_state=42)\nX_train_balanced, y_train_balanced = smote.fit_resample(X_train, y_train)\n\n# Reentrenar el modelo con los datos balanceados\nrf_model_balanced = RandomForestClassifier(random_state=42)\nrf_model_balanced.fit(X_train_balanced, y_train_balanced)\n\n# Hacer predicciones nuevamente\ny_pred_balanced = rf_model_balanced.predict(X_test)\n\n# Evaluar el modelo balanceado\nprint("Accuracy:", accuracy_score(y_test, y_pred_balanced))\nprint("ROC-AUC Score:", roc_auc_score(y_test, y_pred_balanced))\nprint(classification_report(y_test, y_pred_balanced))\n\n'

# %%
'''
from imblearn.over_sampling import ADASYN

# Aplicar ADASYN para el balanceo de clases
adasyn = ADASYN(random_state=42)
X_train_adasyn, y_train_adasyn = adasyn.fit_resample(X_train, y_train)

# Entrenar el modelo de RandomForest con el nuevo conjunto balanceado
rf_model_adasyn = RandomForestClassifier(
    n_estimators=best_params['n_estimators'],
    max_depth=best_params['max_depth'],
    min_samples_split=best_params['min_samples_split'],
    min_samples_leaf=best_params['min_samples_leaf'],
    random_state=42
)

rf_model_adasyn.fit(X_train_adasyn, y_train_adasyn)

# Hacer predicciones
y_pred_adasyn = rf_model_adasyn.predict(X_test)

# Evaluar el modelo
print("ADASYN Accuracy:", accuracy_score(y_test, y_pred_adasyn))
print("ADASYN ROC-AUC Score:", roc_auc_score(y_test, y_pred_adasyn))
print(classification_report(y_test, y_pred_adasyn))

'''
# Out:
# '\nfrom imblearn.over_sampling import ADASYN\n\n# Aplicar ADASYN para el balanceo de clases\nadasyn = ADASYN(random_state=42)\nX_train_adasyn, y_train_adasyn = adasyn.fit_resample(X_train, y_train)\n\n# Entrenar el modelo de RandomForest con el nuevo conjunto balanceado\nrf_model_adasyn = RandomForestClassifier(\n    n_estimators=best_params[\'n_estimators\'],\n    max_depth=best_params[\'max_depth\'],\n    min_samples_split=best_params[\'min_samples_split\'],\n    min_samples_leaf=best_params[\'min_samples_leaf\'],\n    random_state=42\n)\n\nrf_model_adasyn.fit(X_train_adasyn, y_train_adasyn)\n\n# Hacer predicciones\ny_pred_adasyn = rf_model_adasyn.predict(X_test)\n\n# Evaluar el modelo\nprint("ADASYN Accuracy:", accuracy_score(y_test, y_pred_adasyn))\nprint("ADASYN ROC-AUC Score:", roc_auc_score(y_test, y_pred_adasyn))\nprint(classification_report(y_test, y_pred_adasyn))\n\n'

# %%
from imblearn.under_sampling import RandomUnderSampler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, roc_auc_score, classification_report

# Aplicar Undersampling para el balanceo de clases
undersampler = RandomUnderSampler(random_state=42)
X_train_undersampled, y_train_undersampled = undersampler.fit_resample(X_train, y_train)

# Inicializar el modelo de RandomForest con los mejores hiperparámetros
rf_model_undersampled = RandomForestClassifier(
    n_estimators=best_params['n_estimators'],
    max_depth=best_params['max_depth'],
    min_samples_split=best_params['min_samples_split'],
    min_samples_leaf=best_params['min_samples_leaf'],
    random_state=42
)

# Entrenar el modelo con el nuevo conjunto balanceado
rf_model_undersampled.fit(X_train_undersampled, y_train_undersampled)

# Hacer predicciones
y_pred_undersampled = rf_model_undersampled.predict(X_test)

# Evaluar el modelo
print("Undersampling Accuracy:", accuracy_score(y_test, y_pred_undersampled))
print("Undersampling ROC-AUC Score:", roc_auc_score(y_test, y_pred_undersampled))
print(classification_report(y_test, y_pred_undersampled))
# Out:
# Undersampling Accuracy: 0.651505016722408
# Undersampling ROC-AUC Score: 0.7192425311691367
#               precision    recall  f1-score   support
#
#            0       0.98      0.64      0.78      1417
#            1       0.11      0.79      0.19        78
#
#     accuracy                           0.65      1495
#    macro avg       0.55      0.72      0.49      1495
# weighted avg       0.94      0.65      0.75      1495

# %% [markdown]
# Probar con LightGBM

# %%
import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_auc_score, classification_report

# Definir la función objetivo para Optuna
def objective(trial):
    # Sugerir hiperparámetros
    param = {
        'objective': 'binary',
        'metric': 'binary_logloss',
        'is_unbalance': True,  # Manejar el desbalance de clases
        'learning_rate': trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
        'num_leaves': trial.suggest_int('num_leaves', 20, 150),
        'min_data_in_leaf': trial.suggest_int('min_data_in_leaf', 20, 100),
        'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
        'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
        'bagging_freq': trial.suggest_int('bagging_freq', 1, 10),
        'min_sum_hessian_in_leaf': trial.suggest_float('min_sum_hessian_in_leaf', 1e-3, 10)
    }

    # Crear dataset para LightGBM
    lgb_train = lgb.Dataset(X_train_undersampled, label=y_train_undersampled)

    # Entrenar el modelo
    lgb_model = lgb.train(param, lgb_train, num_boost_round=100)

    # Predecir
    y_pred_lgb = lgb_model.predict(X_test)
    y_pred_lgb_binary = (y_pred_lgb > 0.5).astype(int)

    # Evaluar el F1-score (puedes cambiar esta métrica si deseas optimizar otra cosa)
    return roc_auc_score(y_test, y_pred_lgb_binary)

# Crear un estudio de Optuna y optimizarlo
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)

# Imprimir los mejores hiperparámetros
print("Best parameters:", study.best_params)
# Out:
# [I 2024-10-09 17:48:18,054] A new study created in memory with name: no-name-17f121df-2256-4670-8b36-ab576a2b0abf
# C:\Users\WINDOWS\AppData\Local\Temp\ipykernel_20456\1932543167.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\WINDOWS\AppData\Local\Temp\ipykernel_20456\1932543167.py:15: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
# ...

# %%
# Obtener los mejores parámetros
best_params = study.best_params

# Agregar otros parámetros necesarios
best_params.update({
    'objective': 'binary',
    'metric': 'binary_logloss',
    'is_unbalance': True  # Mantener el manejo del desbalance de clases
})

# Crear el dataset para LightGBM
lgb_train = lgb.Dataset(X_train_undersampled, label=y_train_undersampled)

# Entrenar el modelo con los mejores parámetros
lgb_model = lgb.train(best_params, lgb_train, num_boost_round=100)

# Hacer predicciones
y_pred_lgb = lgb_model.predict(X_test)
y_pred_lgb_binary = (y_pred_lgb > 0.5).astype(int)

# Evaluar el rendimiento del modelo
print("LightGBM Accuracy:", accuracy_score(y_test, y_pred_lgb_binary))
print("LightGBM ROC-AUC Score:", roc_auc_score(y_test, y_pred_lgb_binary))
print(classification_report(y_test, y_pred_lgb_binary))
# Out:
# [LightGBM] [Info] Number of positive: 170, number of negative: 170
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000183 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 25
# [LightGBM] [Info] Number of data points in the train set: 340, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %% [markdown]
# Feature importances

# %%
'''
# Mostrar las características más importantes
importances = rf_model_adasyn.feature_importances_
feature_names = X.columns

# Crear un DataFrame para visualizarlas
feature_importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': importances})
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# Mostrar las características más importantes
print(feature_importance_df)
'''
# Out:
# "\n# Mostrar las características más importantes\nimportances = rf_model_adasyn.feature_importances_\nfeature_names = X.columns\n\n# Crear un DataFrame para visualizarlas\nfeature_importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': importances})\nfeature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)\n\n# Mostrar las características más importantes\nprint(feature_importance_df)\n"

# %%
# Obtener las importancias de las características
importances = lgb_model.feature_importance()
feature_names = X.columns

# Crear un DataFrame para visualizarlas
feature_importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': importances})
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# Mostrar las características más importantes
print(feature_importance_df)
# Out:
#           Feature  Importance
# 7       age_group          70
# 5  Residence_type          50
# 9   glucose_group          40
# 8       bmi_group          29
# 6  smoking_status          25
# 4       work_type          17
# 0          gender          10
# 1    hypertension           0
# 2   heart_disease           0
# 3    ever_married           0

# %%
# Visualizar las importancias
plt.figure(figsize=(10, 6))
plt.barh(feature_importance_df['Feature'], feature_importance_df['Importance'], color='lightblue')
plt.xlabel('Importance')
plt.title('Feature Importances')
plt.gca().invert_yaxis()  # Invertir el eje y para que la característica más importante esté arriba
plt.show()
